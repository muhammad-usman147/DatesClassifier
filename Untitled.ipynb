# %%
import requests

# %%
data = requests.get("https://www.shutterstock.com/search/medjool+dates")

# %%
data.text
# Out:
# '<!DOCTYPE html><html lang="en" class="no-js" data-reactroot=""><head><meta data-react-helmet="true" http-equiv="X-UA-Compatible" content="IE=edge"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1"/><meta data-react-helmet="true" name="apple-itunes-app" content="app-id=473347409, app-argument=http://www.shutterstock.com/"/><meta data-react-helmet="true" name="google-site-verification" content="1wsiFwGziBzqCcMecpMDlbZgN1jKL-Fh6m05QXpg4QY"/><meta data-react-helmet="true" name="twitter:site" content="@shutterstock"/><meta data-react-helmet="true" name="description" content="Find medjool dates stock images in HD and millions of other royalty-free stock photos, illustrations and vectors in the Shutterstock collection.  Thousands of new, high-quality pictures added every day."/><title data-react-helmet="true">Medjool Dates Images, Stock Photos &amp; Vectors | Shutterstock</title><meta charSet="utf-8"/><script charSet="UTF-8">document.head.parentN
# ...
